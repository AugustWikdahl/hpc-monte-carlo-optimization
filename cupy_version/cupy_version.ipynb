# %%
import cupy as cp
import numpy as np
import time

def mc_price_option_cupy(S0, K, r, sigma, T, M, I):
    """
    GPU-accelerated Monte Carlo pricing using CuPy.
    """
    dt = T / M
    # Allocate memory directly on the GPU
    S = cp.zeros((M + 1, I))
    S[0] = S0

    # Constant values for the simulation (calculate once)
    mu = (r - 0.5 * sigma ** 2) * dt
    vol_sqrt_dt = sigma * cp.sqrt(dt)

    # Generate random paths
    for t in range(1, M + 1):
        eps = cp.random.standard_normal(I)
        S[t] = S[t - 1] * cp.exp(mu + vol_sqrt_dt * eps)

    # Calculate payoff
    payoff = cp.maximum(S[-1] - K, 0)
    C0 = cp.exp(-r * T) * cp.mean(payoff)

    # Wait for the GPU to finish threads
    cp.cuda.Device(0).synchronize()

    return C0, S

def main():
    S0 = 100.0
    K = 105.0
    r = 0.05
    sigma = 0.12
    T = 0.5
    M = 1000
    I = 50_000

    # First run is a "warm-up"
    mc_price_option_cupy(S0, K, r, sigma, T, M, I)

    # Actual timed run
    C0, S_gpu = mc_price_option_cupy(S0, K, r, sigma, T, M, I)
    used_bytes = cp.get_default_memory_pool().used_bytes()
    used_mb = used_bytes / (1024 ** 2)
    print(f"GPU VRAM Used: {used_mb:.2f} MB")

    # Transfer results back to CPU
    C0_cpu = float(C0)

    print(f">> Initial Stock Price: {S0}")
    print("="*28)
    print(f">> GPU European Option Value: {C0_cpu}")
    print("="*28)

# %%
import cupy as cp
import numpy as np
import time
import matplotlib.pyplot as plt

def mc_price_option_cupy(S0, K, r, sigma, T, M, I):
    """
    GPU-accelerated Monte Carlo pricing using CuPy.
    """
    dt = T / M
    # Allocate memory on the GPU
    S = cp.zeros((M + 1, I))
    S[0] = S0

    # Constant values for the simulation
    mu = (r - 0.5 * sigma ** 2) * dt
    vol_sqrt_dt = sigma * cp.sqrt(dt)

    # Generate random paths
    for t in range(1, M + 1):
        eps = cp.random.standard_normal(I)
        S[t] = S[t - 1] * cp.exp(mu + vol_sqrt_dt * eps)

    # Calculate payoff
    payoff = cp.maximum(S[-1] - K, 0)
    C0 = cp.exp(-r * T) * cp.mean(payoff)

    # Wait for the GPU to finish threads
    cp.cuda.Device(0).synchronize()

    return C0, S

def run_gpu_benchmark():
    S0, K, r, sigma, T = 100.0, 105.0, 0.05, 0.12, 0.5
    I_values = [10000, 25000, 50000, 75000, 100000]
    M_values = [100, 500, 1000, 2500, 5000]

    # Lists to store the plot data
    path_total = []
    path_exec = []
    step_total = []
    step_exec = []

    print("Starting benchmark:")

    # Warm-up run
    _ = mc_price_option_cupy(S0, K, r, sigma, T, 100, 1000)

    # 1. Path Scaling (Fixed M=1000)
    print(f"\n{'Dimension':<10} | {'Value':<10} | {'Total Time (s)':<15} | {'Execution Time (s)':<18}")
    print("-" * 65)

    fixed_M = 1000
    for I in I_values:
        t0 = time.perf_counter()
        # Option pricing
        C0, S_gpu = mc_price_option_cupy(S0, K, r, sigma, T, fixed_M, I)
        t1 = time.perf_counter()

        # Memory Transfer back to CPU
        S_cpu = cp.asnumpy(S_gpu)
        t2 = time.perf_counter()

        total_t = t2 - t0
        exec_t = t1 - t0

        path_total.append(total_t)
        path_exec.append(exec_t)

        # Output: Total (t2-t0) and Execution (t1-t0)
        print(f"{'I':<10} | {I:<10} | {total_t:<15.4f} | {exec_t:<18.4f}")

    # 2. Step Scaling (Fixed I=50,000)
    print(f"\n{'Dimension':<10} | {'Value':<10} | {'Total Time (s)':<15} | {'Execution Time (s)':<18}")
    print("-" * 65)

    fixed_I = 50000
    for M in M_values:
        t0 = time.perf_counter()
        C0, S_gpu = mc_price_option_cupy(S0, K, r, sigma, T, M, fixed_I)
        t1 = time.perf_counter()

        S_cpu = cp.asnumpy(S_gpu)
        t2 = time.perf_counter()

        total_t = t2 - t0
        exec_t = t1 - t0

        step_total.append(total_t)
        step_exec.append(exec_t)

        print(f"{'M':<10} | {M:<10} | {total_t:<15.4f} | {exec_t:<18.4f}")

    # Plotting
    print("\nGenerating performance plots...")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    # Plot 1: Path Scaling
    ax1.plot(I_values, path_total, marker='o', color='red', label='Total Time (inc. PCIe)')
    ax1.plot(I_values, path_exec, marker='s', color='blue', label='Execution Time (GPU only)')
    ax1.set_title('CuPy Path Scaling (Fixed M=1000)')
    ax1.set_xlabel('Number of Paths (I)')
    ax1.set_ylabel('Time (s)')
    ax1.grid(True, linestyle='--', alpha=0.7)
    ax1.legend()

    # Plot 2: Step Scaling
    ax2.plot(M_values, step_total, marker='o', color='red', label='Total Time (inc. PCIe)')
    ax2.plot(M_values, step_exec, marker='s', color='blue', label='Execution Time (GPU only)')
    ax2.set_title('CuPy Step Scaling (Fixed I=50000)')
    ax2.set_xlabel('Number of Time Steps (M)')
    ax2.set_ylabel('Time (s)')
    ax2.grid(True, linestyle='--', alpha=0.7)
    ax2.legend()

    plt.tight_layout()
    plt.savefig('cupy_performance.png', dpi=300)
    plt.show()
    print("Plot saved as 'cupy_performance.png' in Colab files.")

# %%
# Run the benchmark and plot
run_gpu_benchmark()

# Run the single check to print VRAM
main()
# Out:
# Starting benchmark:
#
# Dimension  | Value      | Total Time (s)  | Execution Time (s)
# -----------------------------------------------------------------
# I          | 10000      | 0.1285          | 0.0941
# I          | 25000      | 0.1688          | 0.0959
# I          | 50000      | 0.2449          | 0.0955
# I          | 75000      | 0.3122          | 0.0927
# I          | 100000     | 0.3916          | 0.0956
#
# Dimension  | Value      | Total Time (s)  | Execution Time (s)
# -----------------------------------------------------------------
# M          | 100        | 0.0268          | 0.0103
# M          | 500        | 0.1203          | 0.0456
# M          | 1000       | 0.2433          | 0.0968
# M          | 2500       | 0.6184          | 0.2483
# M          | 5000       | 1.2182          | 0.4778
#
# Generating performance plots...
# Plot saved as 'cupy_performance.png' in Colab files.
# GPU VRAM Used: 381.85 MB
# >> Initial Stock Price: 100.0
# ============================
# >> GPU European Option Value: 2.3546267481926777
# ============================
